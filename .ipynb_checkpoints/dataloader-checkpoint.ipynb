# %%
import numpy as np

# %%
# Read binary file
with open('A-EOG_raw_data_example.bin', "rb") as f:
    byte_data = f.read()  # Read the entire file as bytes


# Function to swap adjacent byte pairs
def swap_adjacent_pairs(hex_str):
    return "".join([hex_str[i:i+2] for i in range(0, len(hex_str), 2)][::-1])
    
def locate_first_a(hex_string_ori):
    index = hex_string_ori.find('aaaaaaaa')
    print(f'We found index of the first aaaaaaaa{index}')
    index = hex_string_ori.find('aaaaaaaa', index+1)
    print(f'We found index of the second aaaaaaaa{index}')
    index = index - 7*8
    print(f'The index {index} is the start of the second chunk of 16 channels')
    return index

def discard_redundant(chunks):
    if chunks and len(chunks[-1]) < 8:
        chunks.pop()  # Remove the last element   
    return chunks

    
# Convert bytes to a hexadecimal string
hex_string_ori = byte_data.hex()
print('----raw data')
# print(hex_string_ori[:28*8])
index = locate_first_a(hex_string_ori)
print(hex_string_ori[index:28*8])
hex_string = hex_string_ori[index:]


chunk_size = 8  # 8 hex characters = 32 bits

ori_chunk = [hex_string[i:i+chunk_size] for i in range(0, len(hex_string), chunk_size)]
print('----Original chunk:')
print(ori_chunk[:14])

# Apply the function to each element in the list
chunks = [swap_adjacent_pairs(item) for item in ori_chunk]
print('----Reversed order of each chunk:')
print(chunks[:20])
discard_redundant(chunks)

print(len(chunks))
print(type(chunks))

# synchronization
# 1. detect 8 digits of a --- done
# 2. locate the beginning of the string --- done
# 3. reorder the every two digits in each chunk element to find the timestamp (8 digits before aaaaaaaa)
# Out:
# ----raw data
# We found index of the first aaaaaaaa46
# We found index of the second aaaaaaaa158
# The index 102 is the start of the second chunk of 16 channels
# 6a02010006c6000105bd0002a1ca0003f1b6000440c40005d90e4a05aaaaaaaa5c1801081abd0009dec3000a6adf000be8cc000c8dbb000d6d02010003
# ----Original chunk:
# ['6a020100', '06c60001', '05bd0002', 'a1ca0003', 'f1b60004', '40c40005', 'd90e4a05', 'aaaaaaaa', '5c180108', '1abd0009', 'dec3000a', '6adf000b', 'e8cc000c', '8dbb000d']
# ----Reversed order of each chunk:
# ['0001026a', '0100c606', '0200bd05', '0300caa1', '0400b6f1', '0500c440', '054a0ed9', 'aaaaaaaa', '0801185c', '0900bd1a', '0a00c3de', '0b00df6a', '0c00cce8', '0d00bb8d', '0001026d', '0100c603', '0200bd0a', '0300caa8', '0400b6f5', '0500c460']
# 815603
# <class 'list'>

# %%
def hex_to_signed_int(hex_str):
    int_value = int(hex_str, 16)
    if int_value >= 2**23:  # If the value is negative in two’s complement
        int_value -= 2**24
    return int_value



def info_from_digit(chunks):
    ch_chunks = []
    vol_chunks = []
    timestamp_chunks = []
    
    count=0
    while len(chunks)%14 != 0:
        chunks.pop()
        
    for idx in range(42*5+42*5, 42*5+42*5+42*5, 14):
        chunk_element = chunks[idx:idx+14]
        print(chunk_element)
        timestamp = hex_to_signed_int(chunk_element[6]) 
        for e_idx, chunk_e in enumerate(chunk_element):
            timestamp_chunks.append(timestamp) 
            
            if e_idx ==6 or e_idx ==7:
                ch = e_idx
                ch_chunks.append(ch)
                signed_vol = np.nan
                vol_chunks.append(signed_vol)
            else:
                # vol
                ch = int(chunk_e[:2], 16)
                ch_chunks.append(ch)
                signed_int = hex_to_signed_int(chunk_e[2:])  # Example: -1
                # print(signed_int)  # Output: -1
                signed_vol = signed_int* 5.00 / (2**(24-1)-1)
                vol_chunks.append(signed_vol)

    return vol_chunks, ch_chunks, timestamp_chunks
                

vol_chunks, ch_chunks, timestamp_chunks = info_from_digit(chunks)           
        
    


    

# chunks[85: 85+14]

# print(timestamp_chunks[:28*4])
# print(vol_chunks[:28*4])
# print(ch_chunks[:28*4])
# Out:
# ['0d00ba87', '000101a2', '0100c588', '0200bbee', '0300ca44', '0400b668', '0500c38e', '054a0ee1', 'aaaaaaaa', '080117e9', '0900bca4', '0a00c326', '0b00defb', '0c00cc7b']
# ['0d00ba6d', '000101a2', '0100c570', '0200bbba', '0300ca2a', '0400b671', '0500c35f', '054a0ee1', 'aaaaaaaa', '080117e4', '0900bc96', '0a00c301', '0b00deda', '0c00cc74']
# ['0d00ba40', '0001019f', '0100c563', '0200bbde', '0300ca17', '0400b657', '0500c376', '054a0ee2', 'aaaaaaaa', '080117d3', '0900bc8d', '0a00c318', '0b00decd', '0c00cc5d']
# ['0d00ba5c', '00010189', '0100c55c', '0200bbca', '0300ca24', '0400b652', '0500c35f', '054a0ee2', 'aaaaaaaa', '080117ce', '0900bc8b', '0a00c2f9', '0b00ded6', '0c00cc62']
# ['0d00ba45', '00010180', '0100c558', '0200bb8f', '0300ca17', '0400b645', '0500c344', '054a0ee2', 'aaaaaaaa', '080117be', '0900bc84', '0a00c2dc', '0b00dec4', '0c00cc69']
# ['0d00ba10', '00010174', '0100c559', '0200bba1', '0300ca0e', '0400b649', '0500c34e', '054a0ee2', 'aaaaaaaa', '080117c3', '0900bc88', '0a00c2e5', '0b00dece', '0c00cc4f']
# ['0d00ba21', '00010185', '0100c535', '0200bbcb', '0300c9fd', '0400b65e', '0500c332', '054a0ee3', 'aaaaaaaa', '080117b1', '0900bc7a', '0a00c2d1', '0b00ded0', '0c00cc51']
# ['0d00ba3e', '00010176', '0100c552', '0200bba3', '0300ca01', '0400b639', '0500c314', '054a0ee3', 'aaaaaaaa', '080117bc', '0900bc7d', '0a00c2ab', '0b00dea3', '0c00cc47']
# ['0d00ba1e', '0001015b', '0100c540', '0200bb64', '0300ca08', '0400b62d', '0500c32c', '054a0ee3', 'aaaaaaaa', '080117cc', '0900bc90', '0a00c2bf', '0b00deb7', '0c00cc3c']
# ['0d00b9e8', '0001014c', '0100c522', '0200bb74', '0300c9f7', '0400b641', '0500c318', '054a0ee3', 'aaaaaaaa', '080117b9', '0900bc83', '0a00c2ba', '0b00dec9', '0c00cc25']
# ['0d00b9f6', '00010157', '0100c535', '0200bb72', '0300c9ec', '0400b63b', '0500c2fb', '054a0ee4', 'aaaaaaaa', '080117c4', '0900bc58', '0a00c29c', '0b00deae', '0c00cc1b']
# ['0d00b9f9', '00010158', '0100c520', '0200bb61', '0300c9f0', '0400b636', '0500c2f1', '054a0ee4', 'aaaaaaaa', '080117a0', '0900bc64', '0a00c28d', '0b00dea4', '0c00cc32']
# ['0d00b9de', '0001014d', '0100c51d', '0200bb4b', '0300c9f4', '0400b625', '0500c2d6', '054a0ee4', 'aaaaaaaa', '080117a5', '0900bc89', '0a00c277', '0b00deb7', '0c00cc3c']
# ['0d00b9d0', '00010177', '0100c52e', '0200bb3b', '0300c9eb', '0400b627', '0500c30b', '054a0ee4', 'aaaaaaaa', '080117ba', '0900bc79', '0a00c2a7', '0b00debe', '0c00cc2b']
# ['0d00b9c2', '0001015e', '0100c52d', '0200bb52', '0300c9f2', '0400b637', '0500c314', '054a0ee5', 'aaaaaaaa', '080117ad', '0900bc67', '0a00c2aa', '0b00deaa', '0c00cc2d']

# %%
# Create DataFrame
import pandas as pd

df = pd.DataFrame({
    'timestamp': timestamp_chunks,
    'channel': ch_chunks,
    'voltage': vol_chunks
})

df[14*10:14*12]
# Out:
#      timestamp  channel   voltage
# 140   67159125       13  0.028628
# 141   67159125        0  0.039425
# 142   67159125        1  0.030240
# 143   67159125        2  0.028845
# 144   67159125        3  0.030912
# 145   67159125        4  0.027904
# 146   67159125        6       NaN
# 147   67159125        7       NaN
# 148   67159125      170 -3.333334
# 149   67159125        8  0.042785
# 150   67159125        9  0.028850
# 151   67159125       10  0.029899
# 152   67159125       11  0.034091
# 153   67159125       12  0.031281
# 154   67159149       13  0.028618
# 155   67159149        0  0.039430
# 156   67159149        1  0.030209
# 157   67159149        2  0.028840
# 158   67159149        3  0.030922
# 159   67159149        4  0.027901
# 160   67159149        6       NaN
# 161   67159149        7       NaN
# 162   67159149      170 -3.333334
# 163   67159149        8  0.042774
# 164   67159149        9  0.028841
# 165   67159149       10  0.029914
# 166   67159149       11  0.034083
# 167   67159149       12  0.031281

# %% [markdown]
# input:
# .bin data
#
# output:
# - vol, rotation (rad/degree),
#
#
#
# formula:
# calculation of each angle = linear combination of channels
#
# - aCh1+bCh2+cCh3+dCh4+eCh5+ +Ch8+cCh9 ... +dCh14
#
#
# synchronization
# 1. detect 8 digits of a
# 2. locate the beginning of the string
# 3. reorder the every two digits in each chunk element to find the timestamp (8 digits before aaaaaaaa)
#
# calibration:
# linear scaling.
# - manual input of scaling factor
# - automatic estimation of the factor
#
# considerations:
# - how to synchronize between illustration and recording.
# - the scaling factor is different across two eyes.
#    - scaling factor per angle (?)
#    - 4 cali points (ref1, ref2, ref3, ref4), (actual1,.. actual4) -> how to combine the set of angles?
#
# - Currently the timestamp starts from the hardware

# %%
    # if (idx+1) == 7:
    #         # timestamp
            
    #         # ch
    #         ch = 6
    #         # vol
    #         signed_vol = np.nan
            
    #         timestamp_chunks.append(timestamp)
    #         ch_chunks.append(ch)
    #         vol_chunks.append(signed_vol)
    #     elif (count+1) == 8:
    #         # indicator aaaaaaaa
    #         # timestamp
    #         timestamp = np.nan 
    #         # ch
    #         ch = 7
    #         # vol
    #         signed_vol = np.nan
            
    #         timestamp_chunks.append(timestamp)
    #         ch_chunks.append(ch)
    #         vol_chunks.append(signed_vol)
            
    #     else:
    #         # timestamp
    #         timestamp = np.nan 
    #         # vol
    #         signed_int = hex_to_signed_int(chunk_element[2:])  # Example: -1
    #         # print(signed_int)  # Output: -1
    #         signed_vol = signed_int* 5.00 / (2**(24-1)-1)
    #         # ch
    #         ch = hex_to_signed_int(chunk_element[:2])  # Example: -1
            
    #         timestamp_chunks.append(timestamp)
    #         ch_chunks.append(ch)
    #         vol_chunks.append(signed_vol)
              
    #     # if count%50000==0:
    #     #     print(f'processing {count}/{len(chunks)}')
    #     count = (count+1)%14
    # return vol_chunks, ch_chunks, timestamp_chunks
